# %%
### IMPORTING LIBRARIES

# %%
import pandas as pd
import spacy
from spacy import displacy
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load SpaCy English model
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
#  Load and Prepare Text

# %%
with open(r"C:\Users\henry\OneDrive\20th-century\Key_Events_20th_Century.txt", "r", encoding="utf-8", errors="ignore") as file:
    text = file.read().replace("\n", " ")

# %% [markdown]
# Evaluate and Clean the Text

# %%
# Display the first 500 characters
print(text[:500])
# Out:
#   Key events of the 20th century - Wikipedia                            Jump to content        Main menu      Main menu move to sidebar hide    		Navigation 	   Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us      		Contribute 	   HelpLearn to editCommunity portalRecent changesUpload fileSpecial pages                    Search            Search                       Appearance      Appearance move to sidebar hide  TextSmallStandardLargeThis page always uses small font size

# %%
# Create the NER Object
doc = nlp(text)

# %%
# Visualize Sample Entities
displacy.render(doc[300:1000], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">empires: decolonization         1.5.2
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Cold War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1947–1991
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# )         1.5.3 War by proxy         1.5.4 The space race         1.5.5 The end of
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Cold War         1.5.6 Information
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  and communications technology
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1.6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  The world at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the end of the century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# 2 See also         3 References         4 Sources
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  External links           Key events of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 20th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  languages     العربيةУкраїнська  Edit links            ArticleTalk      English                  ReadEditView history        Tools      Tools move to sidebar hide    		Actions 	   ReadEditView history      		General 	   What links hereRelated changesUpload filePermanent linkPage informationCite this
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pageGet
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  shortened
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     URLDownload
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  QR code Expand allEdit interlanguage links     		Print/export
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Download
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  as PDFPrintable version      		In other projects 	   Wikimedia CommonsWikidata item                            From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wikipedia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , the free encyclopedia
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The 20th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  changed the world in unprecedented ways. The World Wars sparked tension between countries and led to the creation of atomic bombs,
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Cold War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  led to
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Space Race
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  and the creation of space-based rockets, and the World Wide Web was created. These advancements have played a significant role in citizens' lives and shaped
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 21st century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  into what it is
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .   Historic events in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 20th century[edit] World
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at the beginning of the century[edit] Main article:
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Edwardian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  era The new beginning of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 20th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  marked significant changes.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The 1900s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  saw
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the decade
#     <span style=

# %%
# Extract Entities per Sentence
sent_data = []
for sent in doc.sents:
    ents = [ent.text for ent in sent.ents]
    sent_data.append({"sentence": sent.text, "entities": ents})

df_sentences = pd.DataFrame(sent_data)
df_sentences.head()
# Out:
#                                             sentence  \
# 0    Key events of the 20th century - Wikipedia  ...
# 1  Main menu      Main menu move to sidebar hide ...
# 2  Search            Search                      ...
# 3  Color (beta)AutomaticLightDarkThis page is alw...
# 4  Donate  Create account  Log in         Persona...
#
#                                         entities
# 0                             [the 20th century]
# 1  [Navigation \t   Main, Contribute, HelpLearn]
# 2                                             []
# 3                                             []
# 4                      [Log in         Personal]

# %%
# Define Country List
countries = [
    "United States", "Germany", "France", "Russia", "United Kingdom", "Japan",
    "Italy", "China", "India", "Canada", "Austria", "Korea", "Vietnam",
    "Poland", "Spain", "Cuba", "Turkey", "Iraq", "Iran", "Afghanistan"
]

# %%
# Filter Sentences for Country Mentions
def filter_entities(ent_list, country_list):
    return [ent for ent in ent_list if ent in country_list]

df_sentences["country_entities"] = df_sentences["entities"].apply(lambda x: filter_entities(x, countries))

# %%
# Keep Only Sentences with Countries
df_filtered = df_sentences[df_sentences["country_entities"].map(len) > 0]
df_filtered.head()
# Out:
#                                              sentence  \
# 32  After a period of diplomatic and military esca...
# 33  In 1917, Russia ended hostile actions against ...
# 34  The Bolsheviks negotiated the Treaty of Brest-...
# 35  In the treaty, Bolshevik Russia ceded the Balt...
# 36  It also recognized the independence of Ukraine...
#
#                                              entities   country_entities
# 32  [the July Crisis, the end of July 1914, Britis...           [France]
# 33           [1917, Russia, the Central Powers, Tsar]           [Russia]
# 34     [the Treaty of Brest-Litovsk, Germany, Russia]  [Germany, Russia]
# 35  [Bolshevik Russia, Baltic, Germany, Kars Oblas...          [Germany]
# 36               [Germany, Allied, American, 1918.[4]          [Germany]

# %%
# Simplify country names
df_filtered["country_entities"] = df_filtered["country_entities"].apply(lambda x: [item.split()[0] for item in x])
# Out:
# C:\Users\henry\AppData\Local\Temp\ipykernel_34788\35317683.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered["country_entities"] = df_filtered["country_entities"].apply(lambda x: [item.split()[0] for item in x])

# %%
# Create Relationship Pair
relationships = []
for i in range(df_filtered.index[-1]):
    end_i = min(i + 5, df_filtered.index[-1])
    entity_window = sum(df_filtered.loc[i:end_i].country_entities, [])
    unique_entities = [entity_window[i] for i in range(len(entity_window)) if i == 0 or entity_window[i] != entity_window[i-1]]

    if len(unique_entities) > 1:
        for idx, a in enumerate(unique_entities[:-1]):
            b = unique_entities[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
rel_df = pd.DataFrame(relationships)
rel_df = pd.DataFrame(np.sort(rel_df.values, axis=1), columns=rel_df.columns)
rel_df["value"] = 1
rel_df = rel_df.groupby(["source", "target"], sort=False, as_index=False).sum()
rel_df.to_csv("C:/Users/henry/OneDrive/20th-century/country_relationships.csv", index=False)
